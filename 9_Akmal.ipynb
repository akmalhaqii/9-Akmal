# %% [markdown]
# <a href="https://colab.research.google.com/github/akmalhaqii/9-Akmal/blob/main/9_Akmal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Muhammad Akmal Baihaqii")
print ("Kel 9 - DS")
# Out:
# Muhammad Akmal Baihaqii
# Kel 9 - DS
